# %% [markdown]
# <h1>Posttest Praktikum Sistem Informasi </h1>
#
# NIM  : Aminarti
#
# NAMA : 2109116018
#
# > Kerjakanlah tugas berikut berdasarkan instruksi yang diberkan. Kumpulkanlah hasil posttest ini pada Github dengan mengumpulkan link repository kalian.
#
# Disini ada dua jenis tugas.
#
# 1. Visualisasi
# 2. Penerapan Algoritma Naive Bayes
#
#
# Ketentuan pengumpulan tugas :
# 1. Kumpul Tugas ini dengan Format Kelas_NIM_Posttest 1.ipynb
# 2. Kumpulkan dalam bentuk link repository github
# 3. Berikan penjelasan untuk setiap blok kode dengan membuat text atau comment pada kodingan
# 4. Untuk bagian penjelasan gausa terlalu panjang.
# singkat padat dan jelas

# %% [markdown]
# ## Business Understanding & Data Understanding

# %% [markdown]
# Importlah pandas, seaborn, dan plotly
#
# Download dataset dari link ini [**Link Dataset**](https://github.com/fnikolas-r/Data-Mining-Course/blob/main/Pertemuan%202/ChurnBank.csv)
#
#
#
#
# Kemudian taruhlah dalam sebuah variabel bernama df
#
#
# *note: kalian dapat menambah blok yang ada*

# %%
# Melakukan Import library yang diperlukan
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
# Buatlah datasetnya disini 
df = pd.read_csv("ChurnBank.csv")

# %%
# Menampilkan Dataset
df
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
# 19        8226  713700258  Existing Customer            55      F
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# 1       Uneducated        Married     $60K - $80K          Blue        2527.0
# 2          College         Single    $80K - $120K          Blue        3495.0
# 3      High School        Unknown         $120K +          Blue        7793.0
# 4         Graduate         Single  Less than $40K          Blue        2761.0
# 5    Post-Graduate        Unknown    $80K - $120K          Blue       23714.0
# 6      High School         Single     $60K - $80K          Blue       24621.0
# 7         Graduate         Single  Less than $40K          Blue        2370.0
# 8       Uneducated        Married         Unknown          Blue        2404.0
# 9          Unknown         Single    $80K - $120K          Blue        4742.0
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 11      Uneducated        Married    $80K - $120K          Blue       26792.0
# 12     High School        Married         Unknown          Blue        5245.0
# 13      Uneducated         Single     $60K - $80K          Blue       18584.0
# 14      Uneducated         Single         Unknown          Blue        2429.0
# 15        Graduate        Married  Less than $40K          Blue        3111.0
# 16        Graduate        Married  Less than $40K          Blue        7562.0
# 17     High School         Single  Less than $40K          Blue        1438.3
# 18        Graduate         Single     $60K - $80K          Blue        1438.3
# 19   Post-Graduate        Married         Unknown          Blue        2953.0

# %% [markdown]
# ### Business Understanding
#
# Dataset dapat diartikan sebuah kumpulan data atau dokumen yang menyimpan informasi yang dibutuhkan aplikasi atau suatu sistem. Jadi tujuan penggunaan dataset dalam perusahaan ini ialah untuk menyimpan informasi data barang-barang yang didistribusikan.
#
# AmiMart merupakan perusahaan yang bergerak dalam bidang usaha perdagangan barang/retail (minimarket) memiliki maksud dan tujuan diantaranya meningkatkan pelayanan dan kenyamanan konsumen,memenuhi kebutuhan konsumen, pelayanan permintaan dan suplai barang terpenuhi dengan tigkat kecepatan dan efisiensi yang optimal.
#
# Untuk mempermudah menganalisis data dan melihat kecenderungan pembelian barang pada konsumen untuk pola penjualan produk disini menggunakan metode naive bayes.

# %% [markdown]
# ### Data Understanding

# %%
# Dari dataset diatas buatlah  variabel yang berisi
# df1 isinya dataset dengan label target AttiredCustomer
# df2 dengan label bukan Attrired customer
# df3 dengan tabel untuk usia dibawah 50 tahun
# df4 untuk customer yang statusnya itu single

# df1 = 
# df2 = 
# df3 = 
# df4 =

# %%
# df1 isinya dataset dengan label target AttiredCustomer
df1= df[df['Attrition_Flag']==('Attrited Customer')]
df1
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0        6036  720010608  Attrited Customer            37      M
# 1        6684  711323283  Attrited Customer            57      M
# 2        4272  794707083  Attrited Customer            50      M
# 3        9759  709657533  Attrited Customer            44      M
# 4        4740  716625033  Attrited Customer            32      F
# 5        9597  715076358  Attrited Customer            57      M
# 6        5009  804829533  Attrited Customer            59      M
# 7        8200  712144158  Attrited Customer            53      F
# 8        5016  795599883  Attrited Customer            57      F
# 9        8350  709222008  Attrited Customer            41      M
#
#   Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0         Unknown         Single     $40K - $60K          Blue       10226.0
# 1      Uneducated        Married     $60K - $80K          Blue        2527.0
# 2         College         Single    $80K - $120K          Blue        3495.0
# 3     High School        Unknown         $120K +          Blue        7793.0
# 4        Graduate         Single  Less than $40K          Blue        2761.0
# 5   Post-Graduate        Unknown    $80K - $120K          Blue       23714.0
# 6     High School         Single     $60K - $80K          Blue       24621.0
# 7        Graduate         Single  Less than $40K          Blue        2370.0
# 8      Uneducated        Married         Unknown          Blue        2404.0
# 9         Unknown         Single    $80K - $120K          Blue        4742.0

# %%
# df2 dengan label bukan Attrired customer
df2= df[df['Attrition_Flag']!=('Attrited Customer')]
df2
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
# 19        8226  713700258  Existing Customer            55      F
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 11      Uneducated        Married    $80K - $120K          Blue       26792.0
# 12     High School        Married         Unknown          Blue        5245.0
# 13      Uneducated         Single     $60K - $80K          Blue       18584.0
# 14      Uneducated         Single         Unknown          Blue        2429.0
# 15        Graduate        Married  Less than $40K          Blue        3111.0
# 16        Graduate        Married  Less than $40K          Blue        7562.0
# 17     High School         Single  Less than $40K          Blue        1438.3
# 18        Graduate         Single     $60K - $80K          Blue        1438.3
# 19   Post-Graduate        Married         Unknown          Blue        2953.0

# %%
# df3 dengan tabel untuk usia dibawah 50 tahun
df3 = df[df["Customer_Age"] < 50 ]
df3
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# 3      High School        Unknown         $120K +          Blue        7793.0
# 4         Graduate         Single  Less than $40K          Blue        2761.0
# 9          Unknown         Single    $80K - $120K          Blue        4742.0
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 12     High School        Married         Unknown          Blue        5245.0
# 13      Uneducated         Single     $60K - $80K          Blue       18584.0
# 14      Uneducated         Single         Unknown          Blue        2429.0
# 15        Graduate        Married  Less than $40K          Blue        3111.0
# 16        Graduate        Married  Less than $40K          Blue        7562.0
# 17     High School         Single  Less than $40K          Blue        1438.3
# 18        Graduate         Single     $60K - $80K          Blue        1438.3

# %%
# df4 untuk customer yang statusnya itu single
df4= df[df['Marital_Status']==('Single')]
df4
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 2         4272  794707083  Attrited Customer            50      M
# 4         4740  716625033  Attrited Customer            32      F
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# 2          College         Single    $80K - $120K          Blue        3495.0
# 4         Graduate         Single  Less than $40K          Blue        2761.0
# 6      High School         Single     $60K - $80K          Blue       24621.0
# 7         Graduate         Single  Less than $40K          Blue        2370.0
# 9          Unknown         Single    $80K - $120K          Blue        4742.0
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 13      Uneducated         Single     $60K - $80K          Blue       18584.0
# 14      Uneducated         Single         Unknown          Blue        2429.0
# 17     High School         Single  Less than $40K          Blue        1438.3
# 18        Graduate         Single     $60K - $80K          Blue        1438.3

# %% [markdown]
# DATASET
# * df1 : Dataframe ini berisikan pada attrition flag yang datanya ialah attrited customer saja.
# * df2 : Dataframe ini berisikan pada attrition flag yang datanya **bukan** attrited customer.
# * df3 : Dataframe ini berisikan yang usia customer dibawah dari 50 tahun
# * df4 : Dataframe ini berisikan yang statusnya berstatus 'single'.

# %%
# Tampilkan info dataset (df.info()) dan berikan penjelasannya dalam bentuk teks atau comment
(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       20 non-null     int64
#  1   CLIENTNUM        20 non-null     int64
#  2   Attrition_Flag   20 non-null     object
#  3   Customer_Age     20 non-null     int64
#  4   Gender           20 non-null     object
#  5   Education_Level  20 non-null     object
#  6   Marital_Status   20 non-null     object
#  7   Income_Category  20 non-null     object
#  8   Card_Category    20 non-null     object
#  9   Credit_Limit     20 non-null     float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.7+ KB

# %% [markdown]
# df.info merupakan metode info() mencetak informasi tentang DataFrame.
#
# Informasi tersebut berisi jumlah kolom, label kolom, tipe data kolom, penggunaan memori, indeks rentang, dan jumlah sel di setiap kolom (nilai bukan nol).

# %%
#@title Opsional (nilai plus)

# Tampilkan nilai rata-rata, min,max, dan standar deviasi  untuk setiap kolom bertipe angka
print('==MENAMPILKAN NILAI RATA-RATA==')  
print('Nilai Rata-rata Customer_Age \t:', df.Customer_Age.mean())
print('Nilai Rata-rata Credit_Limit \t:', df.Credit_Limit.mean())
print('Nilai Rata-rata CLIENTNUM \t:', df.CLIENTNUM.mean())
print('Nilai Rata-rata Unnamed :0 \t:', df["Unnamed: 0"].mean())
print('\t')
print('==MENAMPILKAN NILAI MINIMUM==')  
print('Nilai Min Customer_Age \t:', df.Customer_Age.min())
print('Nilai Min Credit_Limit \t:', df.Credit_Limit.min())
print('Nilai Min CLIENTNUM \t:', df.CLIENTNUM.min())
print('Nilai Min Unnamed :0 \t:', df["Unnamed: 0"].min())
print('\t')
print('==MENAMPILKAN NILAI MAKSIMUM==')
print('Nilai Max Customer_Age \t:', df.Customer_Age.max())
print('Nilai Max Credit_Limit \t:', df.Credit_Limit.max())
print('Nilai Max CLIENTNUM \t:', df.CLIENTNUM.max())
print('Nilai Max Unnamed :0 \t:', df["Unnamed: 0"].max())
print('\t')
print('==MENAMPILKAN NILAI STANDAR DEVIASI==')  
print('Nilai standar deviasi Customer_Age \t:', df.Customer_Age.std())
print('Nilai standar deviasi Credit_Limit \t:', df.Credit_Limit.std())
print('Nilai standar deviasi CLIENTNUM \t:', df.CLIENTNUM.std())
print('Nilai standar deviasi Unnamed :0 \t:', df["Unnamed: 0"].std())
print('\t')
# Out:
# ==MENAMPILKAN NILAI RATA-RATA==
# Nilai Rata-rata Customer_Age 	: 47.25
# Nilai Rata-rata Credit_Limit 	: 8114.579999999999
# Nilai Rata-rata CLIENTNUM 	: 742489304.25
# Nilai Rata-rata Unnamed :0 	: 6105.1
#
# ==MENAMPILKAN NILAI MINIMUM==
# Nilai Min Customer_Age 	: 32
# Nilai Min Credit_Limit 	: 1438.3
# Nilai Min CLIENTNUM 	: 709222008
# Nilai Min Unnamed :0 	: 176
#
# ==MENAMPILKAN NILAI MAKSIMUM==
# Nilai Max Customer_Age 	: 59
# Nilai Max Credit_Limit 	: 26792.0
# Nilai Max CLIENTNUM 	: 809844108
# Nilai Max Unnamed :0 	: 10084
#
# ==MENAMPILKAN NILAI STANDAR DEVIASI==
# Nilai standar deviasi Customer_Age 	: 7.859791077978707
# Nilai standar deviasi Credit_Limit 	: 8331.036819444947
# Nilai standar deviasi CLIENTNUM 	: 40455244.91809004
# Nilai standar deviasi Unnamed :0 	: 2850.304026258473

# %%
# Secara Otomatis
df.describe()
# Out:
#          Unnamed: 0     CLIENTNUM  Customer_Age  Credit_Limit
# count     20.000000  2.000000e+01     20.000000     20.000000
# mean    6105.100000  7.424893e+08     47.250000   8114.580000
# std     2850.304026  4.045524e+07      7.859791   8331.036819
# min      176.000000  7.092220e+08     32.000000   1438.300000
# 25%     4695.750000  7.120726e+08     41.000000   2502.500000
# 50%     6299.000000  7.173934e+08     47.500000   4118.500000
# 75%     8206.500000  7.822994e+08     53.500000   8621.000000
# max    10084.000000  8.098441e+08     59.000000  26792.000000

# %% [markdown]
# #### Explore Data

# %% [markdown]
# ##### Visualisasi Comparison

# %%
# Buatlah visualisasi yang menampilkan berapa banyak yang attired customer dan tidak
sns.countplot(data=df,x="Attrition_Flag")
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
# Buatlah visualisasi yang menampilkan berapa banyak Education level berdasarkan kategori-kategorinya 
# contoh Unknown berapa dsb
sns.countplot(data=df,x="Education_Level", hue='Education_Level')
# Out:
# <AxesSubplot:xlabel='Education_Level', ylabel='count'>

# %%
# Buatlah visualisasi yang menampilkan berapa banyak Education level berdasarkan gendernya
# contoh M berapa F berapa
sns.countplot(data=df,x="Education_Level", hue="Gender")
# Out:
# <AxesSubplot:xlabel='Education_Level', ylabel='count'>

# %% [markdown]
# Visualisasi Comparison
# * Countplot untuk melihat perbandingan jumlah data, berapa banyak yang attired customer dan tidak, terdapat dua data yaitu : attired customer dan existing customer.
# * Countplot untuk melihat perbandingan jumlah data dari berapa banyak educational level sesuai kategorinya.
# * Countplot untuk melihat perbandingan jumlah data dari berapa banyak Education level berdasarkan gendernya yaitu : Male dan Female.

# %% [markdown]
# ##### Visualisasi Distribution

# %%
# Buatlah historgram untuk customer dan credit card limit
# Histogram umur customer 
sns.histplot(data=df,x="Customer_Age",kde=True)
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Count'>

# %%
# Buatlah historgram untuk customer dan credit card limit
# Histogram credit card limit
sns.histplot(data=df,x="Credit_Limit",kde=True)
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Count'>

# %%
# Buatlah boxplot untuk customer dan credit card limit
# Boxplot umur customer
sns.boxplot(data=df, x="Customer_Age")
# Out:
# <AxesSubplot:xlabel='Customer_Age'>

# %%
# Buatlah boxplot untuk customer dan credit card limit
# Boxplot credit card limit
sns.boxplot(data=df, x="Credit_Limit")
# Out:
# <AxesSubplot:xlabel='Credit_Limit'>

# %% [markdown]
# Visualisasi Distibution
# * Histogram umur customer yang melihat frekuensi rentang usia dari customer dalam histogram.
# * Histogram credit card limit yang melihat frekuensi credit card limit pada setiap customer dalam histogram
# * Boxplot umur customer untuk menampilkan distribusi persebaran usia customer.
# * Boxplot  credit card limit untuk menampilkan distribusi credit limit para customer

# %% [markdown]
# ##### Visualisasi Relationship

# %%
# Buatlah scatterplot untuk umur customer dan credit card limit
sns.scatterplot(data=df, x="Customer_Age", y="Credit_Limit")
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Credit_Limit'>

# %% [markdown]
# Visualisasi Relationship menggunakan scatterplot yang disebut juga grafik sebar untuk menunjukkan nilai dan mengamati hubungan antar dua variabel yaitu customer age dan credit limit.

# %% [markdown]
# ##### Visualisasi Composition

# %%
# Buatlah pieplot untuk Income Category & Education Level
# pieplot untuk Income Category
px.pie(df,names="Income_Category")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e591e4b0-38ce-49b1-a43f-5d8ec4e6a19d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e591e4b0-38ce-49b1-a43f-5d8ec4e6a19d")) {                    Plotly.newPlot(                        "e591e4b0-38ce-49b1-a43f-5d8ec4e6a19d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Income_Category=%{label}<extra></extra>","labels":["$40K - $60K","$60K - $80K","$80K - $120K","$120K +","Less than $40K","$80K - $120K","$60K - $80K","Less than $40K","Unknown","$80K - $120K","$60K - $80K","$80K - $120K","Unknown","$60K - $80K","Unknown","Less than $40K","Less than $40K","Less than $40K","$60K - $80K","Unknown"],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"m ...

# %%
# Buatlah pieplot untuk Income Category & Education Level
# pieplot untuk Education Level
px.pie(df,names="Education_Level")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c2430570-f16b-4926-8705-f9257cc3b238" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2430570-f16b-4926-8705-f9257cc3b238")) {                    Plotly.newPlot(                        "c2430570-f16b-4926-8705-f9257cc3b238",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Education_Level=%{label}<extra></extra>","labels":["Unknown","Uneducated","College","High School","Graduate","Post-Graduate","High School","Graduate","Uneducated","Unknown","Doctorate","Uneducated","High School","Uneducated","Uneducated","Graduate","Graduate","High School","Graduate","Post-Graduate"],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinew ...

# %% [markdown]
# Visualisasi Composition
# * Pieplot untuk memvisualisasikan persebaran dari income category sesuai data.
# * Pieplot untuk memvisualisasikan persebaran dari educational level sesuai data.
#
# Dalam bentuk persen dan warna yang berbeda-beda.

# %% [markdown]
# ### Opsional (Nilai Plus)

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Jenis Kelamin sebagai pemisahnya (color)
sns.boxplot(data=df, x="Credit_Limit",hue="Gender")
# Out:
# <AxesSubplot:xlabel='Credit_Limit'>

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Attrition Flag sebagai pemisahnya (color)
sns.boxplot(data=df, x="Credit_Limit", hue="Attrition_Flag")
# Out:
# <AxesSubplot:xlabel='Credit_Limit'>

# %%
# Buatlah visualisasi boxplot Age dengan Attrition Flag sebagai pemisahnya (color)
sns.boxplot(data=df, x="Customer_Age", hue="Attrition_Flag")
# Out:
# <AxesSubplot:xlabel='Customer_Age'>

# %%
# Buatlah visualisasi countplot  Attrition Flag dengan jenis kelamin sebagai pemisahnya (color)
sns.countplot(data=df, x='Attrition_Flag', hue='Gender')
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
# Buatlah visualisasi heatmap untuk Setiap variabel numerik yang ada
sns.heatmap(df.corr(),cmap='Blues', annot= True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Visualisasi Boxplot
# * Boxplot credit card limit untuk menampilkan distibusi dengan pemisah menggunakan jenis kelamin (gender). Garis ditengah merupakan pemisah.
# * Boxplot Credit Card Limit untuk menampilkan distibusi dengan Attrition Flag sebagai pemisahnya.
# * Boxplot Age untuk menampilkan distibusi dengan Attrition Flag sebagai pemisahnya.
#
# Visualisasi Countplot untuk perbandingan data pada Attrition Flag dengan jenis kelamin sebagai pemisahnya.
#
# Visualisasi heatmap menampilkan data dengan cara representasi warna yang berbeda-beda untuk Setiap variabel numerik yang ada.

# %% [markdown]
# # Algoritma Naive Bayes dan Preprocessing (pengenalan)

# %%
# sebelum membuat algoritma pertama tama buatlah dataset baru dengan ketentuan
# mengambil dataset df
# Menghapus kolom Unnamed: 0, CLIENTNUM, Umur, dan Limit Kartu Kredit (initinya yang berupa primary key dan bukan tipe kategori)
# dataset dengan kolom yang sudah dihapus tadi kemudian disimpan di dataframe baru (df baru)

# %%
df_baru = df.drop(columns=['Unnamed: 0','CLIENTNUM','Customer_Age','Credit_Limit'])
df_baru
# Out:
#        Attrition_Flag Gender Education_Level Marital_Status Income_Category  \
# 0   Attrited Customer      M         Unknown         Single     $40K - $60K
# 1   Attrited Customer      M      Uneducated        Married     $60K - $80K
# 2   Attrited Customer      M         College         Single    $80K - $120K
# 3   Attrited Customer      M     High School        Unknown         $120K +
# 4   Attrited Customer      F        Graduate         Single  Less than $40K
# 5   Attrited Customer      M   Post-Graduate        Unknown    $80K - $120K
# 6   Attrited Customer      M     High School         Single     $60K - $80K
# 7   Attrited Customer      F        Graduate         Single  Less than $40K
# 8   Attrited Customer      F      Uneducated        Married         Unknown
# 9   Attrited Customer      M         Unknown         Single    $80K - $120K
# 10  Existing Customer      M       Doctorate         Single     $60K - $80K
# 11  Existing Customer      M      Uneducated        Married    $80K - $120K
# 12  Existing Customer      F     High School        Married         Unknown
# 13  Existing Customer      M      Uneducated         Single     $60K - $80K
# 14  Existing Customer      F      Uneducated         Single         Unknown
# 15  Existing Customer      F        Graduate        Married  Less than $40K
# 16  Existing Customer      F        Graduate        Married  Less than $40K
# 17  Existing Customer      F     High School         Single  Less than $40K
# 18  Existing Customer      M        Graduate         Single     $60K - $80K
# 19  Existing Customer      F   Post-Graduate        Married         Unknown
#
#    Card_Category
# 0           Blue
# 1           Blue
# 2           Blue
# 3           Blue
# 4           Blue
# 5           Blue
# 6           Blue
# 7           Blue
# 8           Blue
# 9           Blue
# 10          Blue
# 11          Blue
# 12          Blue
# 13          Blue
# 14          Blue
# 15          Blue
# 16          Blue
# 17          Blue
# 18          Blue
# 19          Blue

# %%
# Buatlah sebuah fungsi naive bayes dengan ketentuan
# Mengambil data dari dataframe yang telah diproses pada blok sebelumnya (diatas)
# Nama fungsinya adalah naive_bayes
# Mengambil 1 saja parameter yaitu sebuah list berisi kategori

# Outputnya berupa prediksi Attrited Customer atau Existing Customer
# Outputnya berupa tuple (_hasilnya, persentasenya berapa) contoh (Existing Customer, 0.004)

# Tidak boleh menggunakan library manapun selain pandas dan numpy



# contoh
# def naive_bayes(prediksi:list)-> tuple :
#   ........

# jadi nanti saat saya coba masukan data 
# naive_bayes(["F",	"Uneducated","Single", "Unknown	Blue"]) akan keluar tuple berupa ("Attired Customer", 0.002)

# %%
def naive_bayes(prediksi:list)-> tuple :
    attrited = df_baru[df_baru["Attrition_Flag"]=="Attrited Customer"]
    existing = df_baru[df_baru["Attrition_Flag"]=="Existing Customer"]
    
    # prior probability
    attrited_prior = len(attrited) / len(df_baru)
    existing_prior = len(existing) / len(df_baru)
    
    # likelihood
    for i in range(len(prediksi)):
        attrited_subset = attrited[attrited.iloc[:,i]==prediksi[i]]
        existing_subset = existing[existing.iloc[:,i]==prediksi[i]]
        
        attrited_posterior = (len(attrited_subset) + 1) / (len(attrited) + len(df_baru.iloc[:,i].unique()))
        existing_posterior = (len(existing_subset) + 1) / (len(existing) + len(df_baru.iloc[:,i].unique()))
        
        if i == 0:
            attrited_likelihood = attrited_posterior
            existing_likelihood = existing_posterior
        else:
            attrited_likelihood *= attrited_posterior
            existing_likelihood *= existing_posterior
    
    # posterior probability
    attrited_posterior = attrited_prior * attrited_likelihood
    existing_posterior = existing_prior * existing_likelihood
    
    # normalize posterior probability
    persentasenya = existing_posterior / (attrited_posterior + existing_posterior)
    hasilnya = "Existing Customer" if persentasenya >= 0.5 else "Attrited Customer"

    return (hasilnya, persentasenya)

hasil = naive_bayes(["F", "Uneducated", "Single", "Unknown", "Blue"])
print(hasil)
# Out:
# ('Attrited Customer', 0.25)
